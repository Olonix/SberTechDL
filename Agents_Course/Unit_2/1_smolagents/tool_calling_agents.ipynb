# %% [markdown]
# # Writing actions as code snippets or JSON blobs
#
# This notebook is part of the [Hugging Face Agents Course](https://www.hf.co/learn/agents-course), a free Course from beginner to expert, where you learn to build Agents.
#
# ![Agents course share](https://huggingface.co/datasets/agents-course/course-images/resolve/main/en/communication/share.png)

# %% [markdown]
# ## Let's install the dependencies and login to our HF account to access the Inference API
#
# If you haven't installed `smolagents` yet, you can do so by running the following command:

# %%
# !pip install smolagents -U
# Out:
# Requirement already satisfied: smolagents in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (1.24.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.31.2 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from smolagents) (0.36.2)
# Requirement already satisfied: requests>=2.32.3 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from smolagents) (2.33.1)
# Requirement already satisfied: rich>=13.9.4 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from smolagents) (15.0.0)
# Requirement already satisfied: jinja2>=3.1.4 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from smolagents) (3.1.6)
# Requirement already satisfied: pillow>=10.0.1 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from smolagents) (12.2.0)
# Requirement already satisfied: python-dotenv in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from smolagents) (1.2.2)
# Requirement already satisfied: filelock in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (2026.4.0)
# Requirement already satisfied: packaging>=20.9 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (4.67.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents) (4.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from jinja2>=3.1.4->smolagents) (3.0.3)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from requests>=2.32.3->smolagents) (3.4.7)
# Requirement already satisfied: idna<4,>=2.5 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from requests>=2.32.3->smolagents) (3.13)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from requests>=2.32.3->smolagents) (2.7.0)
# Requirement already satisfied: certifi>=2023.5.7 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from requests>=2.32.3->smolagents) (2026.4.22)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from rich>=13.9.4->smolagents) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from rich>=13.9.4->smolagents) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->smolagents) (0.1.2)
# Requirement already satisfied: colorama in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from tqdm>=4.42.1->huggingface-hub<1.0.0,>=0.31.2->smolagents) (0.4.6)
# [notice] A new release of pip available: 22.3.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %% [markdown]
# Let's also login to the Hugging Face Hub to have access to the Inference API.

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## Selecting a Playlist for the Party Using `smolagents` and a `ToolCallingAgent`
#
# Let's revisit the previous example where Alfred started party preparations, but this time we'll use a `ToolCallingAgent` to highlight the difference. We'll build an agent that can search the web, just like in our Code Agent example. The only difference is the agent type - the framework handles everything else:

# %%
# !pip install smolagents[litellm]
# Out:
# Requirement already satisfied: smolagents[litellm] in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (1.24.0)
# Requirement already satisfied: huggingface-hub<1.0.0,>=0.31.2 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from smolagents[litellm]) (0.36.2)
# Requirement already satisfied: requests>=2.32.3 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from smolagents[litellm]) (2.33.1)
# Requirement already satisfied: rich>=13.9.4 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from smolagents[litellm]) (15.0.0)
# Requirement already satisfied: jinja2>=3.1.4 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from smolagents[litellm]) (3.1.6)
# Requirement already satisfied: pillow>=10.0.1 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from smolagents[litellm]) (12.2.0)
# Requirement already satisfied: python-dotenv in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from smolagents[litellm]) (1.2.2)
# Collecting litellm>=1.60.2
#   Downloading litellm-1.83.14-py3-none-any.whl (16.5 MB)
#      -------------------------------------- 16.5/16.5 MB 494.8 kB/s eta 0:00:00
# Requirement already satisfied: filelock in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[litellm]) (3.29.0)
# Requirement already satisfied: fsspec>=2023.5.0 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[litellm]) (2026.4.0)
# Requirement already satisfied: packaging>=20.9 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[litellm]) (26.2)
# Requirement already satisfied: pyyaml>=5.1 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[litellm]) (6.0.3)
# Requirement already satisfied: tqdm>=4.42.1 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[litellm]) (4.67.3)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from huggingface-hub<1.0.0,>=0.31.2->smolagents[litellm]) (4.15.0)
# Requirement already satisfied: MarkupSafe>=2.0 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from jinja2>=3.1.4->smolagents[litellm]) (3.0.3)
# Collecting fastuuid==0.14.0
#   Downloading fastuuid-0.14.0-cp311-cp311-win_amd64.whl (156 kB)
#      ------------------------------------ 156.1/156.1 kB 405.2 kB/s eta 0:00:00
# Collecting httpx==0.28.1
#   Using cached httpx-0.28.1-py3-none-any.whl (73 kB)
# Collecting openai==2.24.0
#   Downloading openai-2.24.0-py3-none-any.whl (1.1 MB)
#      ---------------------------------------- 1.1/1.1 MB 260.2 kB/s eta 0:00:00
# Collecting tiktoken==0.12.0
#   Downloading tiktoken-0.12.0-cp311-cp311-win_amd64.whl (879 kB)
#      ------------------------------------ 879.4/879.4 kB 337.2 kB/s eta 0:00:00
# Collecting importlib-metadata==8.5.0
#   Using cached importlib_metadata-8.5.0-py3-none-any.whl (26 kB)
# Collecting tokenizers==0.22.2
#   Downloading tokenizers-0.22.2-cp39-abi3-win_amd64.whl (2.7 MB)
#      ---------------------------------------- 2.7/2.7 MB 335.6 kB/s eta 0:00:00
# Collecting click==8.1.8
#   Downloading click-8.1.8-py3-none-any.whl (98 kB)
#      -------------------------------------- 98.2/98.2 kB 511.3 kB/s eta 0:00:00
# Collecting aiohttp==3.13.4
#   Downloading aiohttp-3.13.4-cp311-cp311-win_amd64.whl (463 kB)
#      ------------------------------------ 463.8/463.8 kB 236.1 kB/s eta 0:00:00
# Collecting pydantic==2.12.5
#   Downloading pydantic-2.12.5-py3-none-any.whl (463 kB)
#      ------------------------------------ 463.6/463.6 kB 568.8 kB/s eta 0:00:00
# Collecting jsonschema==4.23.0
#   Using cached jsonschema-4.23.0-py3-none-any.whl (88 kB)
# Collecting aiohappyeyeballs>=2.5.0
#   Using cached aiohappyeyeballs-2.6.1-py3-none-any.whl (15 kB)
# Collecting aiosignal>=1.4.0
#   Using cached aiosignal-1.4.0-py3-none-any.whl (7.5 kB)
# Collecting attrs>=17.3.0
#   Using cached attrs-26.1.0-py3-none-any.whl (67 kB)
# Collecting frozenlist>=1.1.1
#   Using cached frozenlist-1.8.0-cp311-cp311-win_amd64.whl (44 kB)
# Collecting multidict<7.0,>=4.5
#   Downloading multidict-6.7.1-cp311-cp311-win_amd64.whl (45 kB)
#      -------------------------------------- 46.0/46.0 kB 576.5 kB/s eta 0:00:00
# Collecting propcache>=0.2.0
#   Downloading propcache-0.5.2-cp311-cp311-win_amd64.whl (42 kB)
#      ---------------------------------------- 42.1/42.1 kB 2.0 MB/s eta 0:00:00
# Collecting yarl<2.0,>=1.17.0
#   Downloading yarl-1.23.0-cp311-cp311-win_amd64.whl (87 kB)
#      -------------------------------------- 87.5/87.5 kB 410.7 kB/s eta 0:00:00
# Requirement already satisfied: colorama in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from click==8.1.8->litellm>=1.60.2->smolagents[litellm]) (0.4.6)
# Collecting anyio
#   Using cached anyio-4.13.0-py3-none-any.whl (114 kB)
# Requirement already satisfied: certifi in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from httpx==0.28.1->litellm>=1.60.2->smolagents[litellm]) (2026.4.22)
# Collecting httpcore==1.*
#   Using cached httpcore-1.0.9-py3-none-any.whl (78 kB)
# Requirement already satisfied: idna in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from httpx==0.28.1->litellm>=1.60.2->smolagents[litellm]) (3.13)
# Collecting zipp>=3.20
#   Downloading zipp-3.23.1-py3-none-any.whl (10 kB)
# Collecting jsonschema-specifications>=2023.03.6
#   Using cached jsonschema_specifications-2025.9.1-py3-none-any.whl (18 kB)
# Collecting referencing>=0.28.4
#   Using cached referencing-0.37.0-py3-none-any.whl (26 kB)
# Collecting rpds-py>=0.7.1
#   Using cached rpds_py-0.30.0-cp311-cp311-win_amd64.whl (236 kB)
# Collecting distro<2,>=1.7.0
#   Using cached distro-1.9.0-py3-none-any.whl (20 kB)
# Collecting jiter<1,>=0.10.0
#   Downloading jiter-0.14.0-cp311-cp311-win_amd64.whl (204 kB)
#      ------------------------------------ 204.7/204.7 kB 621.1 kB/s eta 0:00:00
# Collecting sniffio
#   Using cached sniffio-1.3.1-py3-none-any.whl (10 kB)
# Collecting annotated-types>=0.6.0
#   Using cached annotated_types-0.7.0-py3-none-any.whl (13 kB)
# Collecting pydantic-core==2.41.5
#   Downloading pydantic_core-2.41.5-cp311-cp311-win_amd64.whl (2.0 MB)
#      ---------------------------------------- 2.0/2.0 MB 564.2 kB/s eta 0:00:00
# Collecting typing-inspection>=0.4.2
#   Using cached typing_inspection-0.4.2-py3-none-any.whl (14 kB)
# Collecting regex>=2022.1.18
#   Downloading regex-2026.4.4-cp311-cp311-win_amd64.whl (278 kB)
#      ------------------------------------ 278.4/278.4 kB 612.2 kB/s eta 0:00:00
# Collecting h11>=0.16
#   Using cached h11-0.16.0-py3-none-any.whl (37 kB)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from requests>=2.32.3->smolagents[litellm]) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from requests>=2.32.3->smolagents[litellm]) (2.7.0)
# Requirement already satisfied: markdown-it-py>=2.2.0 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from rich>=13.9.4->smolagents[litellm]) (4.2.0)
# Requirement already satisfied: pygments<3.0.0,>=2.13.0 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from rich>=13.9.4->smolagents[litellm]) (2.20.0)
# Requirement already satisfied: mdurl~=0.1 in d:\sbt_study\sbertechdl\agents_course\unit_2\.venv\lib\site-packages (from markdown-it-py>=2.2.0->rich>=13.9.4->smolagents[litellm]) (0.1.2)
# Installing collected packages: zipp, typing-inspection, sniffio, rpds-py, regex, pydantic-core, propcache, multidict, jiter, h11, frozenlist, fastuuid, distro, click, attrs, anyio, annotated-types, aiohappyeyeballs, yarl, tiktoken, referencing, pydantic, importlib-metadata, httpcore, aiosignal, tokenizers, jsonschema-specifications, httpx, aiohttp, openai, jsonschema, litellm
#   Attempting uninstall: click
#     Found existing installation: click 8.3.3
#     Uninstalling click-8.3.3:
#       Successfully uninstalled click-8.3.3
# Successfully installed aiohappyeyeballs-2.6.1 aiohttp-3.13.4 aiosignal-1.4.0 annotated-types-0.7.0 anyio-4.13.0 attrs-26.1.0 click-8.1.8 distro-1.9.0 fastuuid-0.14.0 frozenlist-1.8.0 h11-0.16.0 httpcore-1.0.9 httpx-0.28.1 importlib-metadata-8.5.0 jiter-0.14.0 jsonschema-4.23.0 jsonschema-specifications-2025.9.1 litellm-1.83.14 multidict-6.7.1 openai-2.24.0 propcache-0.5.2 pydantic-2.12.5 pydantic-core-2.41.5 referencing-0.37.0 regex-2026.4.4 rpds-py-0.30.0 sniffio-1.3.1 tiktoken-0.12.0 tokenizers-0.22.2 typing-inspection-0.4.2 yarl-1.23.0 zipp-3.23.1
# [notice] A new release of pip available: 22.3.1 -> 26.1.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
from smolagents import ToolCallingAgent, WebSearchTool, InferenceClientModel, LiteLLMModel

model = LiteLLMModel(
    model_id="gemini/gemini-3.1-flash-lite",
    api_key="my_gemini_key_was_here"
)

agent = ToolCallingAgent(tools=[WebSearchTool()], model=model)

agent.run("Search for the best music recommendations for a party at the Wayne's mansion.")
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for the best music recommendations for a party at the Wayne's mansion.                                   │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gemini/gemini-3.1-flash-lite ───────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'web_search' with arguments: {'query': 'party music recommendations for Wayne Manor style event'} │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Observations: ## Search Results
#
# |50 Songs on Every Event Planner's Playlist -
# Eventbrite](https://www.eventbrite.com/blog/event-planning-playlist-ds00/)
# Need help choosing the perfect event  music ? Discover how to curate the right playlist with song suggestions from
# Eventbrite.
#
# |The 75 Best Party Songs That Will Get Everyone Dancing -
# Gear4music](https://www.gear4music.com/blog/best-party-songs/)
# Creating a good vibe at your event hinges on selecting the perfect soundtrack. So, let's look at the 75 best party
# songs for your any event .
#
# |late nights in the wayne manor | a bruce wayne rock/blues playlist](https://www.youtube.com/watch?v=oOdHCjj3jn4)
# these are songs that bruce wayne listens to while wandering the halls of the great wayne  manor . find this
# playlist on my spotify: https://open.spotify.com/user ...
#
# |The 10 Best Party Music Playlist Ideas for Any Vibe in 2025](https://1021events.com/best-party-music-playlist/)
# Craft the ultimate soundtrack with our guide to the 10 best party  music playlist ideas, from 80s throwbacks to
# current hits. Perfect for any event !
#
# |Song Lists to Plan Your Event — Pianist for Parties - Sharon Planer](https://pianistforparties.com/songs/)
# Song ideas to help you plan music  for your wedding, corporate event or memorial service, by Event Pianist, Sharon
# Planer.
#
# |Must-Have Playlists for Different Event
# Types](https://www.limelightsent.com/must-have-playlists-for-different-event-types/)
# This blog will explore the art of crafting must-have playlists specifically tailored for different event types,
# focusing on three main occasions: weddings, corporate events , and birthday parties. Playlists for Weddings
# Ceremony Serenades The wedding ceremony is a profound moment that demands music that can evoke emotion and
# reverence.
#
# |GUIDE TO Planning Music for a Party -
# partiesuniverse.com](https://partiesuniverse.com/guide-to-planning-music-for-a-party/)
# There are relatively few high-quality guides about how to plan brilliant music  for a party , so we have decided to
# create our own. Our how-to guide for planning the best music  for a party , is exactly what you need to throw an
# epic celebration where the music completely carries the vibe.
#
# |Best Songs To Party: DJ's Ultimate Party Songs Playlist](https://top40weekly.com/best-songs-to-party/)
# Planning a celebration? Don't forget the music ! We've compiled the best songs to party that are sure to get
# everyone in the mood to dance and have a good time.
#
# |Setting the Perfect Mood: Music Playlists for Every
# Event](https://www.wemassmedia.com/blog/setting-the-perfect-mood-music-playlists-for-every-event)
# The right music can set the tone, energize the crowd, and create lasting memories. Whether you're planning a
# corporate event , wedding, or social gathering, choosing the right playlist is essential. Let's explore some music
# ideas for different types of events and share playlist recommendations to make your event unforgettable.
#
# |Most Popular Music Genres for Parties and How to Blend Them for Maximum
# ...](https://toasttothatent.com/blog/most-popular-music-genres-for-parties-and-how-to-blend-them-for-maximum-impact
# )
# Explore the most popular music genres for parties and learn how to seamlessly blend them for a memorable event .
# [Step 1: Duration 7.74 seconds| Input tokens: 1,121 | Output tokens: 23]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'final_answer' with arguments: {'answer': 'To curate the best music for a party at Wayne Manor,   │
# │ you should aim for a sophisticated yet energetic atmosphere that reflects the prestige of the Wayne family      │
# │ while keeping the vibe lively. Here are some recommendations based on the setting:\n\n1. **The Bruce Wayne      │
# │ Aesthetic (Sophisticated/Mood):** Consider incorporating a "Wayne Manor" vibe, which often leans toward classic │
# │ rock, blues, or ambient, moody tracks that fit the gothic architecture and legacy of the mansion. Search for    │
# │ curated playlists like "late nights in the wayne manor" for inspiration.\n2. **Elevated Party Classics:** Since │
# │ the venue is high-end, mix modern hits with timeless party classics. You can draw from lists like the "75 Best  │
# │ Party Songs" or top-tier event planning guides (e.g., Eventbrite\'s event music suggestions) to ensure the      │
# │ dance floor stays busy.\n3. **Genre Blending:** To cater to a diverse crowd at a prestigious event, blend       │
# │ genres such as 80s throwbacks, jazz/lounge for the cocktail hour, and high-energy current hits for later in the │
# │ evening.\n4. **Professional Curation:** For a truly "Wayne-level" event, consider hiring a professional DJ or   │
# │ pianist who can transition seamlessly between sophisticated background music and high-energy dance tracks, as   │
# │ suggested by specialized event music guides.\n\nUltimately, the best approach is to start with a sophisticated  │
# │ jazz/lounge foundation for the evening\'s arrival and transition into upbeat, universally loved party anthems   │
# │ as the night progresses.'}                                                                                      │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# Observations: To curate the best music for a party at Wayne Manor, you should aim for a sophisticated yet energetic
# atmosphere that reflects the prestige of the Wayne family while keeping the vibe lively. Here are some
# recommendations based on the setting:
#
# 1. **The Bruce Wayne Aesthetic (Sophisticated/Mood):** Consider incorporating a "Wayne Manor" vibe, which often
# leans toward classic rock, blues, or ambient, moody tracks that fit the gothic architecture and legacy of the
# mansion. Search for curated playlists like "late nights in the wayne manor" for inspiration.
# 2. **Elevated Party Classics:** Since the venue is high-end, mix modern hits with timeless party classics. You can
# draw from lists like the "75 Best Party Songs" or top-tier event planning guides (e.g., Eventbrite's event music
# suggestions) to ensure the dance floor stays busy.
# 3. **Genre Blending:** To cater to a diverse crowd at a prestigious event, blend genres such as 80s throwbacks,
# jazz/lounge for the cocktail hour, and high-energy current hits for later in the evening.
# 4. **Professional Curation:** For a truly "Wayne-level" event, consider hiring a professional DJ or pianist who can
# transition seamlessly between sophisticated background music and high-energy dance tracks, as suggested by
# specialized event music guides.
#
# Ultimately, the best approach is to start with a sophisticated jazz/lounge foundation for the evening's arrival and
# transition into upbeat, universally loved party anthems as the night progresses.
# Final answer: To curate the best music for a party at Wayne Manor, you should aim for a sophisticated yet energetic
# atmosphere that reflects the prestige of the Wayne family while keeping the vibe lively. Here are some
# recommendations based on the setting:
#
# 1. **The Bruce Wayne Aesthetic (Sophisticated/Mood):** Consider incorporating a "Wayne Manor" vibe, which often
# leans toward classic rock, blues, or ambient, moody tracks that fit the gothic architecture and legacy of the
# mansion. Search for curated playlists like "late nights in the wayne manor" for inspiration.
# 2. **Elevated Party Classics:** Since the venue is high-end, mix modern hits with timeless party classics. You can
# draw from lists like the "75 Best Party Songs" or top-tier event planning guides (e.g., Eventbrite's event music
# suggestions) to ensure the dance floor stays busy.
# 3. **Genre Blending:** To cater to a diverse crowd at a prestigious event, blend genres such as 80s throwbacks,
# jazz/lounge for the cocktail hour, and high-energy current hits for later in the evening.
# 4. **Professional Curation:** For a truly "Wayne-level" event, consider hiring a professional DJ or pianist who can
# transition seamlessly between sophisticated background music and high-energy dance tracks, as suggested by
# specialized event music guides.
#
# Ultimately, the best approach is to start with a sophisticated jazz/lounge foundation for the evening's arrival and
# transition into upbeat, universally loved party anthems as the night progresses.
# [Step 2: Duration 3.42 seconds| Input tokens: 3,172 | Output tokens: 352]
# 'To curate the best music for a party at Wayne Manor, you should aim for a sophisticated yet energetic atmosphere that reflects the prestige of the Wayne family while keeping the vibe lively. Here are some recommendations based on the setting:\n\n1. **The Bruce Wayne Aesthetic (Sophisticated/Mood):** Consider incorporating a "Wayne Manor" vibe, which often leans toward classic rock, blues, or ambient, moody tracks that fit the gothic architecture and legacy of the mansion. Search for curated playlists like "late nights in the wayne manor" for inspiration.\n2. **Elevated Party Classics:** Since the venue is high-end, mix modern hits with timeless party classics. You can draw from lists like the "75 Best Party Songs" or top-tier event planning guides (e.g., Eventbrite\'s event music suggestions) to ensure the dance floor stays busy.\n3. **Genre Blending:** To cater to a diverse crowd at a prestigious event, blend genres such as 80s throwbacks, jazz/lounge for the cocktail hour, and high-energy current hits for later in the evening.\n4. **Professional Curation:** For a truly "Wayne-level" event, consider hiring a professional DJ or pianist who can transition seamlessly between sophisticated background music and high-energy dance tracks, as suggested by specialized event music guides.\n\nUltimately, the best approach is to start with a sophisticated jazz/lounge foundation for the evening\'s arrival and transition into upbeat, universally loved party anthems as the night progresses.'

# %% [markdown]
# When you examine the agent's trace, instead of seeing `Executing parsed code:`, you'll see something like:
#
# ```text
# ╭─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╮
# │ Calling tool: 'web_search' with arguments: {'query': "best music recommendations for a party at Wayne's         │
# │ mansion"}                                                                                                       │
# ╰─────────────────────────────────────────────────────────────────────────────────────────────────────────────────╯
# ```
#
# The agent generates a structured tool call that the system processes to produce the output, rather than directly executing code like a `CodeAgent`.
#
# Now that we understand both agent types, we can choose the right one for our needs. Let's continue exploring `smolagents` to make Alfred's party a success! 🎉
