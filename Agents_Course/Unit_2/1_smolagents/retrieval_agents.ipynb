# %% [markdown]
# # Building Agentic RAG Systems
#
# This notebook is part of the [Hugging Face Agents Course](https://www.hf.co/learn/agents-course), a free Course from beginner to expert, where you learn to build Agents.
#
# ![Agents course share](https://huggingface.co/datasets/agents-course/course-images/resolve/main/en/communication/share.png)

# %% [markdown]
# ## Let's install the dependencies and login to our HF account to access the Inference API
#
# If you haven't installed `smolagents` yet, you can do so by running the following command:the dependencies and login to our HF account to access the Inference API

# %%
# !pip install smolagents

# %% [markdown]
# Let's also login to the Hugging Face Hub to have access to the Inference API.

# %%
from huggingface_hub import notebook_login

notebook_login()
# Out:
# VBox(children=(HTML(value='<center> <img\nsrc=https://huggingface.co/front/assets/huggingface_logo-noborder.sv…

# %% [markdown]
# ## Basic Retrieval with WebSerach
#
# Let's build a simple agent that can search the web. This agent will retrieve information and synthesize responses to answer queries. With Agentic RAG, Alfred's agent can:
#
# * Search for latest superhero party trends
# * Refine results to include luxury elements
# * Synthesize information into a complete plan
#
# Here's how Alfred's agent can achieve this:

# %%
from smolagents import CodeAgent, WebSearchTool, InferenceClientModel, LiteLLMModel

model = LiteLLMModel(
    model_id="gemini/gemini-3.1-flash-lite",
    api_key=""
)

# Initialize the search tool
search_tool = WebSearchTool()

# Initialize the model
# model = InferenceClientModel()

agent = CodeAgent(
    model = model,
    tools=[search_tool]
)

# Example usage
response = agent.run(
    "Search for luxury superhero-themed party ideas, including decorations, entertainment, and catering."
)
print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Search for luxury superhero-themed party ideas, including decorations, entertainment, and catering.             │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gemini/gemini-3.1-flash-lite ───────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   search_results = web_search(query="luxury superhero themed party ideas decorations entertainment catering")
#   print(search_results)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [15 Ideas for Superhero-Themed Events -
# BizBash](https://www.bizbash.com/event-decor/15-ideas-for-superhero-themed-events)
# 15 Ideas for Superhero-Themed Events Oversize Sculptures In 2008, the Metropolitan Museum of Art 's Costume
# Institute staged an exhibition timed around the release of The Dark Knight titled "Superheroes: Fashion and
# Fantasy," which served as the design springboard for its preview gala. With the help of the movie's set designer,
# Nathan Crowley, the planners placed 20-foot-tall statues of ...
#
# [30+ Superhero Party Ideas - Canva](https://www.canva.com/ideas/superhero-party-ideas/)
# Bright-colored capes, superhero masks for everyone, colorful hero cupcakes - all these ingenious concepts and more
# are in our special selection of superhero-themed designs and photos. Have a quick browse and find some excellent
# ideas for your party !
#
# [Superhero Party Theme - The Bash](https://www.thebash.com/themes/superhero)
# Search food, drink, decoration and entertainment  ideas for putting together a superhero  party theme. Whether
# you're celebrating a birthday or anniversary, find the best party inspiration on The Bash.
#
# [24 Superhero Party Ideas that Will Make You Wish You Were a
# Kid](https://howdoesshe.com/24-incredible-superhero-party-ideas-that-will-make-you-wish-you-were-a-kid-again/)
# 24 incredible superhero  party  ideas that kids will love and make adults wish they were kids again. From decor
# ideas , party foods, and costume ideas to superhero-themed activities, we have all of your party needs covered.
#
# [By a Pro: Superhero Party Ideas by a Professional](https://party-ideas-by-a-pro.com/party-themes/superhero-party/)
#  Superhero  party  ideas by an award winning professional party planner including ideas for invitations, party food
# & drinks, decorations , and party supplies
#
# [25 Superhero Party Ideas For All Ages](https://playideas.com/25-superhero-party-ideas/)
# They are perfect for your next superhero-themed food and party ! We have found some amazingly fantastic party
# ideas from treats, decor, crafts to souvenirs for different sorts of superheroes, from Batman, Super-Man, the Hulk,
# Iron Man, and even villains!.
#
# [Ideas for Superhero-themed Events -
# Pinterest](https://www.pinterest.com/ideas/ideas-for-superhero-themed-events/933271986369/)
# Find and save ideas about ideas for superhero-themed events on Pinterest.
#
# [Superhero-Themed Party Ideas & Decorations |
# CORKCICLE.](https://corkcicle.com/blogs/lifestyle/marvel-themed-party-ideas)
# Marvel™ Superhero-Themed  Party  Ideas  Superhero-themed parties have become a beloved trend, offering an exciting
# way to celebrate special occasions. The thrill of donning capes and masks, the vibrant decorations , and the heroic
# atmosphere make these parties a hit among kids and adults alike.
#
# [Best Superhero Party Theme Ideas - Captain
# Fantastic](https://captain-fantastic.co.uk/blog/best-superhero-party-theme-ideas/)
# Welcome to the realm of excitement and adventure with the Best Superhero  Party Theme Ideas ! Transforming your
# celebration into an epic saga, these ideas ...
#
# [Planning a Superhero Themed Party: Ideas and
# Inspiration](https://partywhammy.com/planning-a-superhero-themed-party-ideas-and-inspiration/)
# If you have a little one that loves superheroes, then what better way to celebrate their birthday or other special
# occasion than with a superhero  themed  party . With the right supplies, decorations and activities, your party can
# be the stuff that dreams are made of! To help you plan a superhero  themed  party your kid will love, here are some
# ideas and inspiration. Decorating Ideas for a ...
#
# Out: None
# [Step 1: Duration 5.28 seconds| Input tokens: 2,225 | Output tokens: 56]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("For a luxury superhero-themed party, elevate the experience with:
#   1. Decorations: Commission oversized statues or sculptures, use immersive projection mapping to transform the
#   venue into a comic-book cityscape, and employ high-end lighting designers to create a 'bat-cave' or 'hero-base'
#   atmosphere.
#   2. Entertainment: Hire professional stunt performers for live-action choreography, provide a luxury photo
#   activation booth with professional lighting and high-quality hero props, or arrange for an interactive 'secret
#   mission' scavenger hunt with high-end prizes.
#   3. Catering: Curate a menu featuring molecular gastronomy 'power-up' snacks, a designer cocktail bar with
#   color-coordinated drinks, and artisanal gourmet 'hero' cupcakes or gold-leafed desserts.
#   Overall, approach the event as an 'immersive gala' rather than a traditional themed party to maintain a
#   high-end feel.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
# ## Search Results
#
# [15 Ideas for Superhero-Themed Events -
# BizBash](https://www.bizbash.com/event-decor/15-ideas-for-superhero-themed-events)
# 15 Ideas for Superhero-Themed Events Oversize Sculptures In 2008, the Metropolitan Museum of Art 's Costume
# Institute staged an exhibition timed around the release of The Dark Knight titled "Superheroes: Fashion and
# Fantasy," which served as the design springboard for its preview gala. With the help of the movie's set designer,
# Nathan Crowley, the planners placed 20-foot-tall statues of ...
#
# [30+ Superhero Party Ideas - Canva](https://www.canva.com/ideas/superhero-party-ideas/)
# Bright-colored capes, superhero masks for everyone, colorful hero cupcakes - all these ingenious concepts and more
# are in our special selection of superhero-themed designs and photos. Have a quick browse and find some excellent
# ideas for your party !
#
# [Superhero Party Theme - The Bash](https://www.thebash.com/themes/superhero)
# Search food, drink, decoration and entertainment  ideas for putting together a superhero  party theme. Whether
# you're celebrating a birthday or anniversary, find the best party inspiration on The Bash.
#
# [24 Superhero Party Ideas that Will Make You Wish You Were a
# Kid](https://howdoesshe.com/24-incredible-superhero-party-ideas-that-will-make-you-wish-you-were-a-kid-again/)
# 24 incredible superhero  party  ideas that kids will love and make adults wish they were kids again. From decor
# ideas , party foods, and costume ideas to superhero-themed activities, we have all of your party needs covered.
#
# [By a Pro: Superhero Party Ideas by a Professional](https://party-ideas-by-a-pro.com/party-themes/superhero-party/)
#  Superhero  party  ideas by an award winning professional party planner including ideas for invitations, party food
# & drinks, decorations , and party supplies
#
# [25 Superhero Party Ideas For All Ages](https://playideas.com/25-superhero-party-ideas/)
# They are perfect for your next superhero-themed food and party ! We have found some amazingly fantastic party
# ideas from treats, decor, crafts to souvenirs for different sorts of superheroes, from Batman, Super-Man, the Hulk,
# Iron Man, and even villains!.
#
# [Ideas for Superhero-themed Events -
# Pinterest](https://www.pinterest.com/ideas/ideas-for-superhero-themed-events/933271986369/)
# Find and save ideas about ideas for superhero-themed events on Pinterest.
#
# [Superhero-Themed Party Ideas & Decorations |
# CORKCICLE.](https://corkcicle.com/blogs/lifestyle/marvel-themed-party-ideas)
# Marvel™ Superhero-Themed  Party  Ideas  Superhero-themed parties have become a beloved trend, offering an exciting
# way to celebrate special occasions. The thrill of donning capes and masks, the vibrant decorations , and the heroic
# atmosphere make these parties a hit among kids and adults alike.
#
# [Best Superhero Party Theme Ideas - Captain
# Fantastic](https://captain-fantastic.co.uk/blog/best-superhero-party-theme-ideas/)
# Welcome to the realm of excitement and adventure with the Best Superhero  Party Theme Ideas ! Transforming your
# celebration into an epic saga, these ideas ...
#
# [Planning a Superhero Themed Party: Ideas and
# Inspiration](https://partywhammy.com/planning-a-superhero-themed-party-ideas-and-inspiration/)
# If you have a little one that loves superheroes, then what better way to celebrate their birthday or other special
# occasion than with a superhero  themed  party . With the right supplies, decorations and activities, your party can
# be the stuff that dreams are made of! To help you plan a superhero  themed  party your kid will love, here are some
# ideas and inspiration. Decorating Ideas for a ...
# Code parsing failed on line 1 due to: SyntaxError: unterminated string literal (detected at line 1) (<unknown>,
# line 1)
# final_answer("For a luxury superhero-themed party, elevate the experience with:               ^
# [Step 2: Duration 12.61 seconds| Input tokens: 5,451 | Output tokens: 367]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 3 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   luxury_tips = (
#       "For a luxury superhero-themed party, elevate the experience with: "
#       "1. Decorations: Commission oversized statues or sculptures, use immersive projection mapping to transform
#   the venue into a comic-book cityscape, and employ high-end lighting designers to create a 'bat-cave' or
#   'hero-base' atmosphere. "
#       "2. Entertainment: Hire professional stunt performers for live-action choreography, provide a luxury photo
#   activation booth with professional lighting and high-quality hero props, or arrange for an interactive 'secret
#   mission' scavenger hunt with high-end prizes. "
#       "3. Catering: Curate a menu featuring molecular gastronomy 'power-up' snacks, a designer cocktail bar with
#   color-coordinated drinks, and artisanal gourmet 'hero' cupcakes or gold-leafed desserts. "
#       "Overall, approach the event as an 'immersive gala' rather than a traditional themed party to maintain a
#   high-end feel."
#   )
#   final_answer(luxury_tips)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: For a luxury superhero-themed party, elevate the experience with: 1. Decorations: Commission
# oversized statues or sculptures, use immersive projection mapping to transform the venue into a comic-book
# cityscape, and employ high-end lighting designers to create a 'bat-cave' or 'hero-base' atmosphere. 2.
# Entertainment: Hire professional stunt performers for live-action choreography, provide a luxury photo activation
# booth with professional lighting and high-quality hero props, or arrange for an interactive 'secret mission'
# scavenger hunt with high-end prizes. 3. Catering: Curate a menu featuring molecular gastronomy 'power-up' snacks, a
# designer cocktail bar with color-coordinated drinks, and artisanal gourmet 'hero' cupcakes or gold-leafed desserts.
# Overall, approach the event as an 'immersive gala' rather than a traditional themed party to maintain a high-end
# feel.
# [Step 3: Duration 7.32 seconds| Input tokens: 10,176 | Output tokens: 621]
# For a luxury superhero-themed party, elevate the experience with: 1. Decorations: Commission oversized statues or sculptures, use immersive projection mapping to transform the venue into a comic-book cityscape, and employ high-end lighting designers to create a 'bat-cave' or 'hero-base' atmosphere. 2. Entertainment: Hire professional stunt performers for live-action choreography, provide a luxury photo activation booth with professional lighting and high-quality hero props, or arrange for an interactive 'secret mission' scavenger hunt with high-end prizes. 3. Catering: Curate a menu featuring molecular gastronomy 'power-up' snacks, a designer cocktail bar with color-coordinated drinks, and artisanal gourmet 'hero' cupcakes or gold-leafed desserts. Overall, approach the event as an 'immersive gala' rather than a traditional themed party to maintain a high-end feel.

# %% [markdown]
# The agent follows this process:
#
# 1. **Analyzes the Request:** Alfred’s agent identifies the key elements of the query—luxury superhero-themed party planning, with focus on decor, entertainment, and catering.
# 2. **Performs Retrieval:**  The agent leverages WebSearchTool to search for the most relevant and up-to-date information, ensuring it aligns with Alfred’s refined preferences for a luxurious event.
# 3. **Synthesizes Information:** After gathering the results, the agent processes them into a cohesive, actionable plan for Alfred, covering all aspects of the party.
# 4. **Stores for Future Reference:** The agent stores the retrieved information for easy access when planning future events, optimizing efficiency in subsequent tasks.

# %% [markdown]
# ## Custom Knowledge Base Tool
#
# For specialized tasks, a custom knowledge base can be invaluable. Let's create a tool that queries a vector database of technical documentation or specialized knowledge. Using semantic search, the agent can find the most relevant information for Alfred's needs.
#
# This approach combines predefined knowledge with semantic search to provide context-aware solutions for event planning. With specialized knowledge access, Alfred can perfect every detail of the party.
#
# Install the dependecies first and run!

# %%
# !pip install langchain langchain-community langchain-text-splitters rank_bm25
# Out:
# Requirement already satisfied: langchain in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (1.2.18)
# Requirement already satisfied: langchain-community in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (0.4.1)
# Requirement already satisfied: langchain-text-splitters in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (1.1.2)
# Requirement already satisfied: rank_bm25 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (0.2.2)
# Requirement already satisfied: langchain-core<2.0.0,>=1.3.3 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langchain) (1.3.3)
# Requirement already satisfied: langgraph<1.2.0,>=1.1.10 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langchain) (1.1.10)
# Requirement already satisfied: pydantic<3.0.0,>=2.7.4 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langchain) (2.12.3)
# Requirement already satisfied: jsonpatch<2.0.0,>=1.33.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (1.33)
# Requirement already satisfied: langchain-protocol>=0.0.10 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (0.0.15)
# Requirement already satisfied: langsmith<1.0.0,>=0.3.45 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (0.8.3)
# Requirement already satisfied: packaging>=23.2.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (26.2)
# Requirement already satisfied: pyyaml<7.0.0,>=5.3.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (6.0.3)
# Requirement already satisfied: tenacity!=8.4.0,<10.0.0,>=8.1.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (9.1.4)
# Requirement already satisfied: typing-extensions<5.0.0,>=4.7.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (4.15.0)
# Requirement already satisfied: uuid-utils<1.0,>=0.12.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langchain-core<2.0.0,>=1.3.3->langchain) (0.14.1)
# Requirement already satisfied: jsonpointer>=1.9 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from jsonpatch<2.0.0,>=1.33.0->langchain-core<2.0.0,>=1.3.3->langchain) (3.1.1)
# Requirement already satisfied: langgraph-checkpoint<5.0.0,>=2.1.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (4.0.3)
# Requirement already satisfied: langgraph-prebuilt<1.1.0,>=1.0.12 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (1.0.13)
# Requirement already satisfied: langgraph-sdk<0.4.0,>=0.3.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (0.3.14)
# Requirement already satisfied: xxhash>=3.5.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langgraph<1.2.0,>=1.1.10->langchain) (3.7.0)
# Requirement already satisfied: ormsgpack>=1.12.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langgraph-checkpoint<5.0.0,>=2.1.0->langgraph<1.2.0,>=1.1.10->langchain) (1.12.2)
# Requirement already satisfied: httpx>=0.25.2 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (0.28.1)
# Requirement already satisfied: orjson>=3.11.5 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (3.11.9)
# Requirement already satisfied: requests-toolbelt>=1.0.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain) (1.0.0)
# Requirement already satisfied: requests>=2.0.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain) (2.33.1)
# Requirement already satisfied: zstandard>=0.23.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain) (0.25.0)
# Requirement already satisfied: anyio in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (4.13.0)
# Requirement already satisfied: certifi in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (2026.4.22)
# Requirement already satisfied: httpcore==1.* in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (1.0.9)
# Requirement already satisfied: idna in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (3.13)
# Requirement already satisfied: h11>=0.16 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from httpcore==1.*->httpx>=0.25.2->langgraph-sdk<0.4.0,>=0.3.0->langgraph<1.2.0,>=1.1.10->langchain) (0.16.0)
# Requirement already satisfied: annotated-types>=0.6.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.7.0)
# Requirement already satisfied: pydantic-core==2.41.4 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (2.41.4)
# Requirement already satisfied: typing-inspection>=0.4.2 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from pydantic<3.0.0,>=2.7.4->langchain) (0.4.2)
# Requirement already satisfied: langchain-classic<2.0.0,>=1.0.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langchain-community) (1.0.7)
# Requirement already satisfied: SQLAlchemy<3.0.0,>=1.4.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langchain-community) (2.0.49)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langchain-community) (3.13.4)
# Requirement already satisfied: dataclasses-json<0.7.0,>=0.6.7 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langchain-community) (0.6.7)
# Requirement already satisfied: pydantic-settings<3.0.0,>=2.10.1 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langchain-community) (2.14.1)
# Requirement already satisfied: httpx-sse<1.0.0,>=0.4.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langchain-community) (0.4.3)
# Requirement already satisfied: numpy>=1.26.2 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from langchain-community) (2.4.4)
# Requirement already satisfied: aiohappyeyeballs>=2.5.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (2.6.1)
# Requirement already satisfied: aiosignal>=1.4.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.4.0)
# Requirement already satisfied: attrs>=17.3.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (26.1.0)
# Requirement already satisfied: frozenlist>=1.1.1 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.8.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (6.7.1)
# Requirement already satisfied: propcache>=0.2.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (0.5.2)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from aiohttp<4.0.0,>=3.8.3->langchain-community) (1.23.0)
# Requirement already satisfied: marshmallow<4.0.0,>=3.18.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (3.26.2)
# Requirement already satisfied: typing-inspect<1,>=0.4.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from dataclasses-json<0.7.0,>=0.6.7->langchain-community) (0.9.0)
# Requirement already satisfied: python-dotenv>=0.21.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from pydantic-settings<3.0.0,>=2.10.1->langchain-community) (1.2.2)
# Requirement already satisfied: charset_normalizer<4,>=2 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain) (3.4.7)
# Requirement already satisfied: urllib3<3,>=1.26 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from requests>=2.0.0->langsmith<1.0.0,>=0.3.45->langchain-core<2.0.0,>=1.3.3->langchain) (2.7.0)
# Requirement already satisfied: greenlet>=1 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from SQLAlchemy<3.0.0,>=1.4.0->langchain-community) (3.5.0)
# Requirement already satisfied: mypy-extensions>=0.3.0 in d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages (from typing-inspect<1,>=0.4.0->dataclasses-json<0.7.0,>=0.6.7->langchain-community) (1.1.0)
# WARNING: Ignoring invalid distribution ~ydantic (d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ydantic (d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages)
# WARNING: Ignoring invalid distribution ~ydantic (d:\SBT_Study\SberTechDL\Agents_Course\Unit_2\.venv\Lib\site-packages)

# %%
from langchain_core.documents import Document
from langchain_text_splitters import RecursiveCharacterTextSplitter
from smolagents import Tool
from langchain_community.retrievers import BM25Retriever
from smolagents import CodeAgent, InferenceClientModel, LiteLLMModel

class PartyPlanningRetrieverTool(Tool):
    name = "party_planning_retriever"
    description = "Uses semantic search to retrieve relevant party planning ideas for Alfred’s superhero-themed party at Wayne Manor."
    inputs = {
        "query": {
            "type": "string",
            "description": "The query to perform. This should be a query related to party planning or superhero themes.",
        }
    }
    output_type = "string"

    def __init__(self, docs, **kwargs):
        super().__init__(**kwargs)
        self.retriever = BM25Retriever.from_documents(
            docs, k=5  # Retrieve the top 5 documents
        )

    def forward(self, query: str) -> str:
        assert isinstance(query, str), "Your search query must be a string"

        docs = self.retriever.invoke(
            query,
        )
        return "\nRetrieved ideas:\n" + "".join(
            [
                f"\n\n===== Idea {str(i)} =====\n" + doc.page_content
                for i, doc in enumerate(docs)
            ]
        )

# Simulate a knowledge base about party planning
party_ideas = [
    {"text": "A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.", "source": "Party Ideas 1"},
    {"text": "Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.", "source": "Entertainment Ideas"},
    {"text": "For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'", "source": "Catering Ideas"},
    {"text": "Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.", "source": "Decoration Ideas"},
    {"text": "Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.", "source": "Entertainment Ideas"}
]

source_docs = [
    Document(page_content=doc["text"], metadata={"source": doc["source"]})
    for doc in party_ideas
]

# Split the documents into smaller chunks for more efficient search
text_splitter = RecursiveCharacterTextSplitter(
    chunk_size=500,
    chunk_overlap=50,
    add_start_index=True,
    strip_whitespace=True,
    separators=["\n\n", "\n", ".", " ", ""],
)
docs_processed = text_splitter.split_documents(source_docs)

# Create the retriever tool
party_planning_retriever = PartyPlanningRetrieverTool(docs_processed)

model = LiteLLMModel(
    model_id="gemini/gemini-3.1-flash-lite",
    api_key="my_gemini_key_was_here"
)

# Initialize the agent
agent = CodeAgent(tools=[party_planning_retriever], model=model)

# Example usage
response = agent.run(
    "Find ideas for a luxury superhero-themed party, including entertainment, catering, and decoration options."
)

print(response)
# Out:
# ╭──────────────────────────────────────────────────── New run ────────────────────────────────────────────────────╮
# │                                                                                                                 │
# │ Find ideas for a luxury superhero-themed party, including entertainment, catering, and decoration options.      │
# │                                                                                                                 │
# ╰─ LiteLLMModel - gemini/gemini-3.1-flash-lite ───────────────────────────────────────────────────────────────────╯
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 1 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   ideas = party_planning_retriever(query="luxury superhero-themed party ideas entertainment catering decoration")
#   print(ideas)
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# Execution logs:
#
# Retrieved ideas:
#
#
# ===== Idea 0 =====
# A superhero-themed masquerade ball with luxury decor, including gold accents and velvet curtains.
#
# ===== Idea 1 =====
# Interactive experiences with VR where guests can engage in superhero simulations or compete in themed games.
#
# ===== Idea 2 =====
# Decorate with iconic superhero logos and projections of Gotham and other superhero cities around the venue.
#
# ===== Idea 3 =====
# For catering, serve dishes named after superheroes, like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak.'
#
# ===== Idea 4 =====
# Hire a professional DJ who can play themed music for superheroes like Batman and Wonder Woman.
#
# Out: None
# [Step 1: Duration 14.36 seconds| Input tokens: 2,235 | Output tokens: 64]
# ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ Step 2 ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━
#  ─ Executing parsed code: ────────────────────────────────────────────────────────────────────────────────────────
#   final_answer("For a luxury superhero-themed party, consider a masquerade ball setting with gold accents and
#   velvet decor. Entertainment options include interactive VR simulations and a professional DJ playing
#   character-themed music. For catering, provide themed dishes like 'The Hulk's Green Smoothie' and 'Iron Man's
#   Power Steak,' and for decoration, use iconic superhero logos and immersive projections of cities like Gotham.")
#  ─────────────────────────────────────────────────────────────────────────────────────────────────────────────────
# <pre style="white-space:pre;overflow-x:auto;line-height:normal;font-family:Menlo,'DejaVu Sans Mono',consolas,'Courier New',monospace"></pre>
# Final answer: For a luxury superhero-themed party, consider a masquerade ball setting with gold accents and velvet
# decor. Entertainment options include interactive VR simulations and a professional DJ playing character-themed
# music. For catering, provide themed dishes like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak,' and for
# decoration, use iconic superhero logos and immersive projections of cities like Gotham.
# [Step 2: Duration 5.55 seconds| Input tokens: 4,752 | Output tokens: 195]
# For a luxury superhero-themed party, consider a masquerade ball setting with gold accents and velvet decor. Entertainment options include interactive VR simulations and a professional DJ playing character-themed music. For catering, provide themed dishes like 'The Hulk's Green Smoothie' and 'Iron Man's Power Steak,' and for decoration, use iconic superhero logos and immersive projections of cities like Gotham.

# %% [markdown]
# This enhanced agent can:
# 1. First check the documentation for relevant information
# 2. Combine insights from the knowledge base
# 3. Maintain conversation context through memory
